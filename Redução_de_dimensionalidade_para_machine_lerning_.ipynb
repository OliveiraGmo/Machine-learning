# %% [markdown]
# <a href="https://colab.research.google.com/github/OliveiraGmo/Machine-learning/blob/main/Redu%C3%A7%C3%A3o_de_dimensionalidade_para_machine_lerning_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2   #importando o modulo do OpenCV
from google.colab.patches import cv2_imshow   #Utilizei O Google colab, tive que importar o cv2_imshow() para exibir a imagem tratada

img = cv2.imread("/content/Lenna.webp")  #aqui carrego a imagem
lenatest = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)   #aqui o cv2 altera de BGR( Blue,Green, Red para Gray )
cv2_imshow(lenatest)  # Aqui exibe a imagem
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=400x400>
