# %% [markdown]
# <a href="https://colab.research.google.com/github/OliveiraGmo/Machine-learning/blob/main/Detectando_imagens_com_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##This is my first attempted to using yolo in colab, i will learn more 
##and put my progress on the same path of git hub

# %pip install ultralytics -q

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.63 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.1/107.7 GB disk)

# %%
image= "/content/dog.jpg" #here you put the path of image the you want to detect
# !yolo predict model=yolov8n.pt source={image}
# Out:
# Ultralytics 8.3.63 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/dog.jpg: 480x640 1 bicycle, 1 car, 1 truck, 1 dog, 349.8ms
# Speed: 19.2ms preprocess, 349.8ms inference, 41.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import matplotlib.pyplot as plt # im using matplotlib to show the image
import matplotlib.image as mpimg
img = mpimg.imread('/content/runs/detect/predict/dog.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
image= "/content/kite.jpg"
# !yolo predict model=yolov8n.pt source={image}
# Out:
# Ultralytics 8.3.63 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/kite.jpg: 448x640 8 persons, 5 kites, 203.6ms
# Speed: 5.1ms preprocess, 203.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
img = mpimg.imread('/content/runs/detect/predict2/kite.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
image= "/content/20181220_104732.jpg"
# !yolo predict model=yolov8n.pt source={image}
img = mpimg.imread('/content/runs/detect/predict4/20181220_104732.jpg') # aleatory image from my phone
imgplot = plt.imshow(img)
plt.show()
# Out:
# Ultralytics 8.3.63 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/20181220_104732.jpg: 640x384 2 cars, 261.7ms
# Speed: 7.4ms preprocess, 261.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
